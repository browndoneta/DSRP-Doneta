# %% [markdown]
# <a href="https://colab.research.google.com/github/browndoneta/DSRP-Doneta/blob/main/Gallstone_Research_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Gallstone Disease Dataset
#  Research Question: How do specific body composition indicators compare to metabolic indicators when predicting the presence of gallstone disease and severity?

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/browndoneta/DSRP-Doneta/refs/heads/main/csv.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    Gallstone Status  Age  Gender  Comorbidity  Coronary Artery Disease (CAD)  \
# 0                 0   50       0            0                              0
# 1                 0   47       0            1                              0
# 2                 0   61       0            0                              0
# 3                 0   41       0            0                              0
# 4                 0   42       0            0                              0
#
#    Hypothyroidism  Hyperlipidemia  Diabetes Mellitus (DM)  Height  Weight  \
# 0               0               0                       0     185    92.8
# 1               0               0                       0     176    94.5
# 2               0               0                       0     171    91.1
# 3               0               0                       0     168    67.7
# 4               0               0                       0     178    89.6
#
#    ...  High Density Lipoprotein (HDL)  Triglyceride  \
# ...

# %%
# !git config --global user.name "browndoneta"
# !git config user.email "browndoneta@gmail.com"
# Out:
# fatal: not in a git directory

# %%
# !git clone https://github.com/browndoneta/DSRP-Doneta.git
# Out:
# Cloning into 'DSRP-Doneta'...
# remote: Enumerating objects: 23, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 23 (delta 7), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (23/23), 118.10 KiB | 4.54 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
# %cd DSRP-Doneta
# Out:
# /content/DSRP-Doneta

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('Gallstone Dataset.csv')
df.head()
# Out:
#      <input type="file" id="files-aaa7fd42-ff74-440a-a4b4-7952b13327e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-aaa7fd42-ff74-440a-a4b4-7952b13327e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319 entries, 0 to 318
# Data columns (total 39 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gallstone Status                                319 non-null    int64
#  1   Age                                             319 non-null    int64
#  2   Gender                                          319 non-null    int64
#  3   Comorbidity                                     319 non-null    int64
#  4   Coronary Artery Disease (CAD)                   319 non-null    int64
#  5   Hypothyroidism                                  319 non-null    int64
#  6   Hyperlipidemia                                  319 non-null    int64
#  7   Diabetes Mellitus (DM)                          319 non-null    int64
#  8   Height                                          319 non-null    int64
# ...

# %%
df.duplicated().sum()
df.drop_duplicates(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.describe()
# Out:
#        Gallstone Status         Age      Gender  Comorbidity  \
# count        319.000000  319.000000  319.000000   319.000000
# mean           0.495298   48.068966    0.492163     0.335423
# std            0.500763   12.114558    0.500724     0.517340
# min            0.000000   20.000000    0.000000     0.000000
# 25%            0.000000   38.500000    0.000000     0.000000
# 50%            0.000000   49.000000    0.000000     0.000000
# 75%            1.000000   56.000000    1.000000     1.000000
# max            1.000000   96.000000    1.000000     3.000000
#
#        Coronary Artery Disease (CAD)  Hypothyroidism  Hyperlipidemia  \
# count                     319.000000      319.000000      319.000000
# mean                        0.037618        0.028213        0.025078
# std                         0.190568        0.165841        0.156609
# min                         0.000000        0.000000        0.000000
# ...

# %%
df = df[df['Age'] > 120]

# %%
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')

# %%
df.isnull().sum()
# Out:
# Gallstone Status                                  0
# Age                                               0
# Gender                                            0
# Comorbidity                                       0
# Coronary Artery Disease (CAD)                     0
# Hypothyroidism                                    0
# Hyperlipidemia                                    0
# Diabetes Mellitus (DM)                            0
# Height                                            0
# Weight                                            0
# Body Mass Index (BMI)                             0
# Total Body Water (TBW)                            0
# Extracellular Water (ECW)                         0
# Intracellular Water (ICW)                         0
# Extracellular Fluid/Total Body Water (ECF/TBW)    0
# Total Body Fat Ratio (TBFR) (%)                   0
# Lean Mass (LM) (%)                                0
# Body Protein Content (Protein) (%)                0
# ...

# %%
df.to_csv("cleaned_data.csv", index=False)

# %%
import seaborn as sns
import matplotlib.pyplot as plt


plt.figure(figsize=(6, 4))
ax = sns.countplot(x='Gallstone Status', data=df)


for p in ax.patches:
 height = p.get_height()
 ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
        ha='center',va='bottom',fontsize=12)


plt.title("Gallstone Disease Prevalence")
plt.xlabel("Gallstone Status")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 39 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Gallstone Status                                0 non-null      int64
#  1   Age                                             0 non-null      int64
#  2   Gender                                          0 non-null      int64
#  3   Comorbidity                                     0 non-null      int64
#  4   Coronary Artery Disease (CAD)                   0 non-null      int64
#  5   Hypothyroidism                                  0 non-null      int64
#  6   Hyperlipidemia                                  0 non-null      int64
#  7   Diabetes Mellitus (DM)                          0 non-null      int64
#  8   Height                                          0 non-null      int64
# ...

# %%
from sklearn.model_selection import train_test_split



# Define feature columns (X) and target (y)
feature_cols = [
'Weight',
'Body Mass Index (BMI)',
'Total Body Fat Ratio (TBFR) (%)',
'Visceral Fat Rating (VFR)',
'Visceral Fat Area (VFA)',
'Lean Mass (LM) (%)',
'Muscle Mass (MM)',
'Total Fat Content (TFC)',
'Obesity (%)',
'Body Protein Content (Protein) (%)',
'Bone Mass (BM)',
'Hepatic Fat Accumulation (HFA)',
'Extracellular Fluid/Total Body Water (ECF/TBW)',
'Glucose',
'Total Cholesterol (TC)',
'Low Density Lipoprotein (LDL)',
'High Density Lipoprotein (HDL)',
'Triglyceride',
'Aspartat Aminotransferaz (AST)',
'Alanin Aminotransferaz (ALT)',
'Alkaline Phosphatase (ALP)',
'Creatinine'
]


df_model = df[feature_cols + ['Gallstone Status']].dropna()


X = df_model[feature_cols]
y = df_model['Gallstone Status']


X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.3, random_state=42, stratify=y
)

print("Training set size:", X_train.shape)
print("Testing set size:", X_test.shape)
# Out:
# Training set size: (223, 22)
# Testing set size: (96, 22)

# %%
import statsmodels.api as sm
import pandas as pd

# Metabolic indicators only
metabolic_indicators = [
'Glucose',
'Total Cholesterol (TC)',
'Low Density Lipoprotein (LDL)',
'High Density Lipoprotein (HDL)',
'Triglyceride',
'Aspartat Aminotransferaz (AST)',
'Alanin Aminotransferaz (ALT)',
'Alkaline Phosphatase (ALP)',
'Creatinine'
]


df_model = df[metabolic_indicators + ['Gallstone Status']].dropna()

X = df_model[metabolic_indicators]
y = df_model['Gallstone Status']


X = sm.add_constant(X)


logit_model = sm.Logit(y, X).fit()


print(logit_model.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.631984
#          Iterations 6
#                            Logit Regression Results
# ...
# Dep. Variable:       Gallstone Status   No. Observations:                  319
# Model:                          Logit   Df Residuals:                      309
# Method:                           MLE   Df Model:                            9
# Date:                Fri, 01 Aug 2025   Pseudo R-squ.:                 0.08818
# Time:                        14:46:27   Log-Likelihood:                -201.60
# converged:                       True   LL-Null:                       -221.10
# Covariance Type:            nonrobust   LLR p-value:                 1.155e-05
# ...
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Are metabolic indicators significantly associated with the presence of gallstone disease?

# %%
# Odds Ratios
import numpy as np

odds_ratios = pd.DataFrame({
"Variable": X.columns,
"Odds Ratio": np.exp(logit_model.params),
"P-Value": logit_model.pvalues
})

print(odds_ratios.sort_values("P-Value"))
# Out:
#                                                       Variable  Odds Ratio  \
# Aspartat Aminotransferaz (AST)  Aspartat Aminotransferaz (AST)    0.915899
# Alanin Aminotransferaz (ALT)      Alanin Aminotransferaz (ALT)    1.042190
# Alkaline Phosphatase (ALP)          Alkaline Phosphatase (ALP)    1.009925
# High Density Lipoprotein (HDL)  High Density Lipoprotein (HDL)    1.025180
# Creatinine                                          Creatinine    0.303048
# Low Density Lipoprotein (LDL)    Low Density Lipoprotein (LDL)    0.988841
# Total Cholesterol (TC)                  Total Cholesterol (TC)    1.007279
# Glucose                                                Glucose    0.998735
# const                                                    const    0.840386
# Triglyceride                                      Triglyceride    1.000102
#
#                                  P-Value
# Aspartat Aminotransferaz (AST)  0.000136
# Alanin Aminotransferaz (ALT)    0.000412
# ...

# %%
# Body composition indicators only
body_comp_indicators = [
'Weight',
'Body Mass Index (BMI)',
'Total Body Fat Ratio (TBFR) (%)',
'Visceral Fat Rating (VFR)',
'Visceral Fat Area (VFA)',
'Lean Mass (LM) (%)',
'Muscle Mass (MM)',
'Total Fat Content (TFC)',
'Obesity (%)',
'Body Protein Content (Protein) (%)',
'Bone Mass (BM)',
'Hepatic Fat Accumulation (HFA)',
'Extracellular Fluid/Total Body Water (ECF/TBW)'
]


import statsmodels.api as sm
import numpy as np
import pandas as pd

df_body = df[body_comp_indicators + ['Gallstone Status']].dropna()


X = df_body[body_comp_indicators]
y = df_body['Gallstone Status']


X = sm.add_constant(X)


logit_model_body = sm.Logit(y, X).fit()


print(logit_model_body.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.568069
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:       Gallstone Status   No. Observations:                  319
# Model:                          Logit   Df Residuals:                      305
# Method:                           MLE   Df Model:                           13
# Date:                Fri, 01 Aug 2025   Pseudo R-squ.:                  0.1804
# Time:                        14:51:17   Log-Likelihood:                -181.21
# converged:                       True   LL-Null:                       -221.10
# Covariance Type:            nonrobust   LLR p-value:                 1.218e-11
# ...
#                                                      coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# ...

# %%
odds_ratios_body = pd.DataFrame({
"Variable": X.columns,
"Odds Ratio": np.exp(logit_model_body.params),
"P-Value": logit_model_body.pvalues
})

print(odds_ratios_body.sort_values("P-Value"))
# Out:
#                                                                                       Variable  \
# Extracellular Fluid/Total Body Water (ECF/TBW)  Extracellular Fluid/Total Body Water (ECF/TBW)
# Bone Mass (BM)                                                                  Bone Mass (BM)
# Weight                                                                                  Weight
# Hepatic Fat Accumulation (HFA)                                  Hepatic Fat Accumulation (HFA)
# Total Fat Content (TFC)                                                Total Fat Content (TFC)
# Total Body Fat Ratio (TBFR) (%)                                Total Body Fat Ratio (TBFR) (%)
# Body Mass Index (BMI)                                                    Body Mass Index (BMI)
# Visceral Fat Area (VFA)                                                Visceral Fat Area (VFA)
# Lean Mass (LM) (%)                                                          Lean Mass (LM) (%)
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns


odds_ratios = np.exp(logit_model.params)
conf = logit_model.conf_int()
conf_odds = np.exp(conf)
p_values = logit_model.pvalues


results_df = pd.DataFrame({
'Variable': odds_ratios.index,
'Odds Ratio': odds_ratios.values,
'CI Lower': conf_odds[0].values,
'CI Upper': conf_odds[1].values,
'P-Value': p_values.values
})


results_df = results_df.sort_values(by='Odds Ratio', ascending=False)

# Plot
plt.figure(figsize=(8, 6))
sns.pointplot(data=results_df, y='Variable', x='Odds Ratio', join=False, color='blue')
plt.errorbar(x=results_df['Odds Ratio'], y=results_df['Variable'],
xerr=[results_df['Odds Ratio'] - results_df['CI Lower'],
results_df['CI Upper'] - results_df['Odds Ratio']],
fmt='none', ecolor='gray', capsize=3)

plt.axvline(x=1, color='red', linestyle='--')
plt.title('Odds Ratios with 95% CI')
plt.xlabel('Odds Ratio')
plt.ylabel('Metabolic Indicator')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-823348226.py:24: UserWarning:
#
# The `join` parameter is deprecated and will be removed in v0.15.0. You can remove the line between points with `linestyle='none'`.
#
#   sns.pointplot(data=results_df, y='Variable', x='Odds Ratio', join=False, color='blue')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd


# logit_model = sm.Logit(y, X).fit()


odds_ratios = np.exp(logit_model.params)
conf = logit_model.conf_int()
conf_odds = np.exp(conf)
p_values = logit_model.pvalues


results_df = pd.DataFrame({
'Variable': odds_ratios.index,
'Odds Ratio': odds_ratios.values,
'CI Lower': conf_odds[0].values,
'CI Upper': conf_odds[1].values,
'P-Value': p_values.values
})


results_df = results_df.sort_values(by='Odds Ratio', ascending=False)

# Plot
plt.figure(figsize=(8, 6))
sns.pointplot(
data=results_df,
y='Variable',
x='Odds Ratio',
color='blue',
linestyles='none',
errorbar=None
)


plt.errorbar(
x=results_df['Odds Ratio'],
y=np.arange(len(results_df)),
xerr=[
results_df['Odds Ratio'] - results_df['CI Lower'],
results_df['CI Upper'] - results_df['Odds Ratio']
],
fmt='none',
ecolor='gray',
capsize=3
)

plt.axvline(x=1, color='red', linestyle='--', linewidth=1)
plt.title('Odds Ratios with 95% CI for Metabolic Predictors of Gallstone Disease')
plt.xlabel('Odds Ratio')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# Since the odds ratio for ALT is above 1, (indicated by the blue dot surpassing the red line), this shows that higher Alanin Aminotraferaz is greatly associated with the chance of gallstone disease.

# %% [markdown]
# Since LDL, HDL, ALP, Glucose, TC, and Triglyceride do not surpass 1, they are not great indicators of Gallstone disease.

# %%
body_composition_features = [
'Body Mass Index (BMI)',
'Total Body Water (TBW)',
'Extracellular Water (ECW)',
'Intracellular Water (ICW)',
'Extracellular Fluid/Total Body Water (ECF/TBW)',
'Total Body Fat Ratio (TBFR) (%)',
'Lean Mass (LM) (%)',
'Body Protein Content (Protein) (%)',
'Visceral Fat Rating (VFR)',
'Bone Mass (BM)',
'Muscle Mass (MM)',
'Obesity (%)',
'Total Fat Content (TFC)',
'Visceral Fat Area (VFA)',
'Visceral Muscle Area (VMA) (Kg)',
'Hepatic Fat Accumulation (HFA)'
]


X_body = df[body_composition_features]
y = df['Gallstone Status']


import statsmodels.api as sm
X_body = sm.add_constant(X_body)

# %%
logit_model_body = sm.Logit(y, X_body).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.555696
#          Iterations 8

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


odds_ratios = np.exp(logit_model_body.params)
conf = np.exp(logit_model_body.conf_int())
p_values = logit_model_body.pvalues


results_df = pd.DataFrame({
'Variable': odds_ratios.index,
'Odds Ratio': odds_ratios.values,
'CI Lower': conf[0].values,
'CI Upper': conf[1].values,
'P-Value': p_values.values
})


results_df = results_df.sort_values(by='Odds Ratio', ascending=False)

# Plot
plt.figure(figsize=(9, 6))
sns.pointplot(
data=results_df,
y='Variable',
x='Odds Ratio',
color='green',
linestyles='none'
)


plt.errorbar(
x=results_df['Odds Ratio'],
y=np.arange(len(results_df)),
xerr=[
results_df['Odds Ratio'] - results_df['CI Lower'],
results_df['CI Upper'] - results_df['Odds Ratio']
],
fmt='none',
ecolor='gray',
capsize=3
)


plt.axvline(x=1, color='red', linestyle='--', linewidth=1)

plt.title('Odds Ratios with 95% CI for Body Composition Predictors of Gallstone Disease')
plt.xlabel('Odds Ratio')
plt.ylabel('')
plt.tight_layout()
plt.show()

# %% [markdown]
# As you may notice, none of the green dots surpass the red line, meaning No body composition indicators are significant indicators of Gallstone Disease.

# %%
import seaborn as sns
import matplotlib.pyplot as plt


metabolic_vars = ['Alanine Aminotransferaz (ALT)', 'Aspartat Aminotransferaz (AST)']


for var in metabolic_vars:
 plt.figure(figsize=(6, 4))
sns.boxplot(data=df, x='Gallstone Status', y=var, palette='Set2')
plt.title(f'{var} by Gallstone Status')
plt.xlabel('Gallstone Status (0 = No, 1 = Yes)')
plt.ylabel(var)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4193650127.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Gallstone Status', y=var, palette='Set2')

# %%
print(df['Gallstone Status'].unique())
# Out:
# [0 1]

# %%
df[['Gallstone Status', 'Alanin Aminotransferaz (ALT)']].dropna()
# Out:
#      Gallstone Status  Alanin Aminotransferaz (ALT)
# 0                   0                          22.0
# 1                   0                          13.0
# 2                   0                          14.0
# 3                   0                          12.0
# 4                   0                          54.0
# ..                ...                           ...
# 314                 1                          50.0
# 315                 1                          16.0
# 316                 1                          27.0
# 317                 1                          22.0
# 318                 1                          73.0
#
# [319 rows x 2 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
data=df,
x='Gallstone Status',
y='Alanin Aminotransferaz (ALT)',
hue='Gallstone Status', # Set hue to the same as x
palette='Set2',
dodge=False, # Ensures single box per group
legend=False # Hides redundant legend
)

plt.title('ALT Levels by Gallstone Status')
plt.xlabel('Gallstone Status (0 = No, 1 = Yes)')
plt.ylabel('ALT Level')
plt.tight_layout()
plt.show()

# %% [markdown]
# The group on the left (0), does not have gallstones, but
